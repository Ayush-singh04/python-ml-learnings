# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("netflix_dataset_raw.csv")

# df.head()
# df.isnull()

# %%
# Cleaning Data
# df.info()
# df.columns.
df.dropna(subset=['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
       'release_year', 'rating', 'duration', 'listed_in', 'description',
       'imdb_score'])
# Out:
#     show_id     type               title            director  \
# 1        s2  TV Show     Horror Tales 22       Robert Taylor
# 2        s3  TV Show     Mystery Show 15        Daniel Clark
# 3        s4    Movie       Love Story 28       Mark Thompson
# 5        s6    Movie  Adventure Quest 65      Jennifer Lopez
# 7        s8  TV Show        The Series 5       Sarah Johnson
# ..      ...      ...                 ...                 ...
# 491    s492    Movie  Animation World 54          John Smith
# 493    s494    Movie  Animation World 67        Daniel Clark
# 494    s495    Movie       Dark Night 93  Michelle Rodriguez
# 498    s499  TV Show    Animation Fun 34       Robert Taylor
# 499    s500  TV Show     Drama Series 15         Kevin Young
#
#                                                   cast  \
# 1    Olivia Brown, Ryan Davis, Ethan Rodriguez, Ame...
# 2    Sophie Taylor, Ava Clark, Benjamin Turner, Mat...
# 3    Matt Anderson, Isabella Adams, Ethan Rodriguez...
# ...

# %%
#  Checking the count of movies vs t.v shows

type_count = df["type"].value_counts()
plt.figure(figsize = (6,4))
plt.bar(type_count.index , type_count.values , color = ['orange','purple'])
plt.title("Number of Movies VS T.V Shows on Netflix")
plt.xlabel("Type of Content")
plt.ylabel("Quantity")

plt.tight_layout()
# plt.savefig("Movies_Vs_TVshows.png")
plt.show()

# %%
# Checking Rating Counts

rating_count = df["rating"].value_counts()
plt.figure(figsize = (8,6))
plt.pie(rating_count, labels = rating_count.index, autopct = "%1.1f%%" , startangle = 90 )

plt.title("Percentage of Content Ratings")


plt.tight_layout()
plt.savefig("Content_Ratings_pie.png")
plt.show()

# %%
# df.info
df.
# Out:
#      show_id   type  title  director   cast  country  date_added  \
# 0      False  False  False      True  False    False       False
# 1      False  False  False     False  False    False       False
# 2      False  False  False     False  False    False       False
# 3      False  False  False     False  False    False       False
# 4      False  False  False      True  False     True       False
# ..       ...    ...    ...       ...    ...      ...         ...
# 495    False  False  False     False  False    False       False
# 496    False  False  False     False   True    False       False
# 497    False  False  False     False   True    False       False
# 498    False  False  False     False  False    False       False
# 499    False  False  False     False  False    False       False
#
#      release_year  rating  duration  listed_in  description  imdb_score
# 0           False   False     False      False        False       False
# ...
